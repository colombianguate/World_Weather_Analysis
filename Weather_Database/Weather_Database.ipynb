# %%
# Dependencies and Setup
import requests
import time
import pandas as pd
from datetime import datetime
from citipy import citipy
import numpy as np


# Import API keys
from config import g_key
from config import weather_api_key

# %%
#create a random latitude and longitude combinations
lat= np.random.uniform(low=-100.00, high= 100.00, size =2000)
lon= np.random.uniform(low=-200.00, high= 200.00, size = 2000)
#add the lat, long to a list
coordinates = list(zip(lat,lon))

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 635

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.

city_data = []

# Create counters.
record_count = 1
set_count = 1



# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Date": city_date,
                          "Currrent Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | ushuaia
# Processing Record 2 of Set 13 | tabriz
# Processing Record 3 of Set 13 | chokurdakh
# Processing Record 4 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 13 | beringovskiy
# Processing Record 6 of Set 13 | faanui
# Processing Record 7 of Set 13 | nau
# Processing Record 8 of Set 13 | haines junction
# Processing Record 9 of Set 13 | basco
# Processing Record 10 of Set 13 | east london
# Processing Record 11 of Set 13 | bengkulu
# Processing Record 12 of Set 13 | the valley
# Processing Record 13 of Set 13 | olinda
# Processing Record 14 of Set 13 | bridlington
# Processing Record 15 of Set 13 | bulaevo
# Processing Record 16 of Set 13 | rikitea
# Processing Record 17 of Set 13 | vaini
# Processing Record 18 of Set 13 | bairnsdale
# Processing Record 19 of Set 13 | daru
# Processing Record 20 of Set 13 | barrow
# Processing Record 21 of Set 13 | arraial do cabo
# Processing Record 22 of Set 13 | sao filipe
# Processing Record 23 of Set 13 | tuktoyaktuk
# Processing Record 24 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 13 | clyde river
# Processing Record 26 of Set 13 | jamestown
# Processing Record 27 of Set 13 | hobart
# Processing Record 28 of Set 13 | hilo
# Processing Record 29 of Set 13 | taltal
# Processing Record 30 of Set 13 | cherskiy
# Processing Record 31 of Set 13 | katsuura
# Processing Record 32 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 13 | muroto
# Processing Record 34 of Set 13 | albany
# Processing Record 35 of Set 13 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 13 | kruisfontein
# Processing Record 37 of Set 13 | kavieng
# Processing Record 38 of Set 13 | new norfolk
# Processing Record 39 of Set 13 | rabo de peixe
# Processing Record 40 of Set 13 | boulder city
# Processing Record 41 of Set 13 | constitucion
# Processing Record 42 of Set 13 | shache
# Processing Record 43 of Set 13 | dezful
# Processing Record 44 of Set 13 | busselton
# Processing Record 45 of Set 13 | grande-riviere
# City not found. Skipping...
# Processing Record 46 of Set 13 | saint-georges
# Processing Record 47 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 13 | bahia blanca
# Processing Record 49 of Set 13 | adrar
# Processing Record 50 of Set 13 | khatanga
# Processing Record 1 of Set 14 | saldanha
# Processing Record 2 of Set 14 | nikolskoye
# Processing Record 3 of Set 14 | mataura
# Processing Record 4 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 14 | husavik
# Processing Record 6 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 14 | kaitangata
# Processing Record 8 of Set 14 | akdepe
# Processing Record 9 of Set 14 | xapuri
# Processing Record 10 of Set 14 | baculin
# Processing Record 11 of Set 14 | saskylakh
# Processing Record 12 of Set 14 | torbay
# Processing Record 13 of Set 14 | punta arenas
# Processing Record 14 of Set 14 | yen bai
# Processing Record 15 of Set 14 | bambous virieux
# Processing Record 16 of Set 14 | thompson
# Processing Record 17 of Set 14 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 14 | bluff
# Processing Record 19 of Set 14 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 14 | avarua
# Processing Record 21 of Set 14 | chuy
# Processing Record 22 of Set 14 | proletariy
# Processing Record 23 of Set 14 | kuhdasht
# Processing Record 24 of Set 14 | puerto ayora
# Processing Record 25 of Set 14 | bubaque
# Processing Record 26 of Set 14 | kodiak
# Processing Record 27 of Set 14 | butaritari
# Processing Record 28 of Set 14 | walvis bay
# Processing Record 29 of Set 14 | brokopondo
# Processing Record 30 of Set 14 | ponta do sol
# Processing Record 31 of Set 14 | geraldton
# Processing Record 32 of Set 14 | nizwa
# Processing Record 33 of Set 14 | victoria
# Processing Record 34 of Set 14 | atchison
# Processing Record 35 of Set 14 | komsomolskiy
# Processing Record 36 of Set 14 | upernavik
# Processing Record 37 of Set 14 | atuona
# Processing Record 38 of Set 14 | berlevag
# Processing Record 39 of Set 14 | yumen
# Processing Record 40 of Set 14 | san quintin
# Processing Record 41 of Set 14 | tiksi
# Processing Record 42 of Set 14 | hithadhoo
# Processing Record 43 of Set 14 | evanston
# Processing Record 44 of Set 14 | mount gambier
# Processing Record 45 of Set 14 | dunedin
# Processing Record 46 of Set 14 | cidreira
# Processing Record 47 of Set 14 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 14 | kapaa
# Processing Record 49 of Set 14 | bonavista
# Processing Record 50 of Set 14 | xining
# Processing Record 1 of Set 15 | hami
# Processing Record 2 of Set 15 | touros
# Processing Record 3 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 4 of Set 15 | ndende
# Processing Record 5 of Set 15 | dikson
# Processing Record 6 of Set 15 | egvekinot
# Processing Record 7 of Set 15 | tautira
# Processing Record 8 of Set 15 | mehamn
# Processing Record 9 of Set 15 | te anau
# Processing Record 10 of Set 15 | fortuna
# Processing Record 11 of Set 15 | seymchan
# Processing Record 12 of Set 15 | qaanaaq
# Processing Record 13 of Set 15 | rostovka
# Processing Record 14 of Set 15 | nanakuli
# Processing Record 15 of Set 15 | anadyr
# Processing Record 16 of Set 15 | castro
# Processing Record 17 of Set 15 | lavrentiya
# Processing Record 18 of Set 15 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 15 | kaputa
# Processing Record 20 of Set 15 | sao miguel do araguaia
# Processing Record 21 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 22 of Set 15 | hereford
# Processing Record 23 of Set 15 | saint-paul
# Processing Record 24 of Set 15 | guymon
# Processing Record 25 of Set 15 | hermanus
# Processing Record 26 of Set 15 | los llanos de aridane
# Processing Record 27 of Set 15 | sao domingos
# Processing Record 28 of Set 15 | cape town
# Processing Record 29 of Set 15 | thanh hoa
# Processing Record 30 of Set 15 | college
# Processing Record 31 of Set 15 | batagay-alyta
# Processing Record 32 of Set 15 | lebu
# Processing Record 33 of Set 15 | rosarito
# Processing Record 34 of Set 15 | malakal
# Processing Record 35 of Set 15 | nouadhibou
# Processing Record 36 of Set 15 | yellowknife
# Processing Record 37 of Set 15 | san felipe
# Processing Record 38 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 15 | bangkalan
# Processing Record 40 of Set 15 | okhotsk
# Processing Record 41 of Set 15 | leningradskiy
# Processing Record 42 of Set 15 | hobyo
# Processing Record 43 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 44 of Set 15 | phangnga
# Processing Record 45 of Set 15 | south lake tahoe
# Processing Record 46 of Set 15 | guntakal
# Processing Record 47 of Set 15 | wanning
# Processing Record 48 of Set 15 | saint-philippe
# Processing Record 49 of Set 15 | laguna
# Processing Record 50 of Set 15 | severo-kurilsk
# Processing Record 1 of Set 16 | moose factory
# Processing Record 2 of Set 16 | hervey bay
# Processing Record 3 of Set 16 | dzhusaly
# City not found. Skipping...
# Processing Record 4 of Set 16 | fort nelson
# Processing Record 5 of Set 16 | french harbor
# Processing Record 6 of Set 16 | benguela
# Processing Record 7 of Set 16 | havoysund
# Processing Record 8 of Set 16 | georgetown
# Processing Record 9 of Set 16 | zhezkazgan
# Processing Record 10 of Set 16 | boa esperanca
# Processing Record 11 of Set 16 | betong
# Processing Record 12 of Set 16 | san isidro
# Processing Record 13 of Set 16 | riva
# Processing Record 14 of Set 16 | pevek
# Processing Record 15 of Set 16 | morant bay
# Processing Record 16 of Set 16 | yulara
# Processing Record 17 of Set 16 | kiunga
# Processing Record 18 of Set 16 | syracuse
# Processing Record 19 of Set 16 | flinders
# Processing Record 20 of Set 16 | bredasdorp
# Processing Record 21 of Set 16 | port alfred
# Processing Record 22 of Set 16 | altona
# Processing Record 23 of Set 16 | atar
# Processing Record 24 of Set 16 | sept-iles
# Processing Record 25 of Set 16 | cayenne
# Processing Record 26 of Set 16 | lufilufi
# Processing Record 27 of Set 16 | nongan
# Processing Record 28 of Set 16 | caravelas
# Processing Record 29 of Set 16 | havre-saint-pierre
# Processing Record 30 of Set 16 | sur
# Processing Record 31 of Set 16 | beloha
# Processing Record 32 of Set 16 | sitka
# Processing Record 33 of Set 16 | saint-augustin
# Processing Record 34 of Set 16 | shimoda
# Processing Record 35 of Set 16 | san jeronimo
# Processing Record 36 of Set 16 | margate
# Processing Record 37 of Set 16 | aklavik
# Processing Record 38 of Set 16 | luanda
# Processing Record 39 of Set 16 | melioratorov
# Processing Record 40 of Set 16 | westport
# Processing Record 41 of Set 16 | skibbereen
# Processing Record 42 of Set 16 | alofi
# Processing Record 43 of Set 16 | northglenn
# Processing Record 44 of Set 16 | asau
# Processing Record 45 of Set 16 | moosomin
# Processing Record 46 of Set 16 | mar del plata
# Processing Record 47 of Set 16 | nola
# Processing Record 48 of Set 16 | luderitz
# Processing Record 49 of Set 16 | shingu
# Processing Record 50 of Set 16 | russell
# Processing Record 1 of Set 17 | sorland
# Processing Record 2 of Set 17 | tucuman
# Processing Record 3 of Set 17 | celestun
# Processing Record 4 of Set 17 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 17 | faya
# Processing Record 6 of Set 17 | narsaq
# Processing Record 7 of Set 17 | hornepayne
# Processing Record 8 of Set 17 | carnarvon
# Processing Record 9 of Set 17 | cabo san lucas
# Processing Record 10 of Set 17 | bur gabo
# City not found. Skipping...
# Processing Record 11 of Set 17 | itoman
# Processing Record 12 of Set 17 | urumqi
# Processing Record 13 of Set 17 | yenagoa
# Processing Record 14 of Set 17 | zolochiv
# Processing Record 15 of Set 17 | athabasca
# Processing Record 16 of Set 17 | deputatskiy
# Processing Record 17 of Set 17 | tuggurt
# City not found. Skipping...
# Processing Record 18 of Set 17 | albertville
# Processing Record 19 of Set 17 | naze
# Processing Record 20 of Set 17 | kimbe
# Processing Record 21 of Set 17 | ola
# Processing Record 22 of Set 17 | mahajanga
# Processing Record 23 of Set 17 | katangli
# Processing Record 24 of Set 17 | airai
# Processing Record 25 of Set 17 | lashma
# Processing Record 26 of Set 17 | bathsheba
# Processing Record 27 of Set 17 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 17 | valparaiso
# Processing Record 29 of Set 17 | san cristobal
# Processing Record 30 of Set 17 | doha
# Processing Record 31 of Set 17 | pacific grove
# Processing Record 32 of Set 17 | huarmey
# Processing Record 33 of Set 17 | maiduguri
# Processing Record 34 of Set 17 | zhigansk
# Processing Record 35 of Set 17 | saint george
# Processing Record 36 of Set 17 | kitui
# Processing Record 37 of Set 17 | quatre cocos
# Processing Record 38 of Set 17 | coquimbo
# Processing Record 39 of Set 17 | mantua
# Processing Record 40 of Set 17 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 17 | saint anthony
# Processing Record 42 of Set 17 | kilindoni
# Processing Record 43 of Set 17 | vanavara
# Processing Record 44 of Set 17 | rincon
# Processing Record 45 of Set 17 | sibolga
# Processing Record 46 of Set 17 | ndioum
# Processing Record 47 of Set 17 | san patricio
# Processing Record 48 of Set 17 | danilov
# Processing Record 49 of Set 17 | bethel
# Processing Record 50 of Set 17 | itamarandiba
# Processing Record 1 of Set 18 | iqaluit
# Processing Record 2 of Set 18 | amga
# Processing Record 3 of Set 18 | hambantota
# Processing Record 4 of Set 18 | balkanabat
# Processing Record 5 of Set 18 | kranea elassonos
# Processing Record 6 of Set 18 | bushehr
# Processing Record 7 of Set 18 | tromso
# Processing Record 8 of Set 18 | lata
# Processing Record 9 of Set 18 | ancud
# Processing Record 10 of Set 18 | maldonado
# Processing Record 11 of Set 18 | longyearbyen
# Processing Record 12 of Set 18 | mahibadhoo
# Processing Record 13 of Set 18 | ahipara
# Processing Record 14 of Set 18 | tasiilaq
# Processing Record 15 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 18 | miri
# Processing Record 17 of Set 18 | chowchilla
# Processing Record 18 of Set 18 | carquefou
# Processing Record 19 of Set 18 | kamaishi
# Processing Record 20 of Set 18 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 18 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 18 | karratha
# Processing Record 23 of Set 18 | bilma
# Processing Record 24 of Set 18 | awbari
# Processing Record 25 of Set 18 | hailey
# Processing Record 26 of Set 18 | mae sai
# Processing Record 27 of Set 18 | kavaratti
# Processing Record 28 of Set 18 | jhawarian
# Processing Record 29 of Set 18 | tamandare
# Processing Record 30 of Set 18 | kahului
# Processing Record 31 of Set 18 | igrim
# Processing Record 32 of Set 18 | kirkuk
# Processing Record 33 of Set 18 | olafsvik
# Processing Record 34 of Set 18 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 18 | palana
# Processing Record 36 of Set 18 | tutoia
# Processing Record 37 of Set 18 | pontianak
# Processing Record 38 of Set 18 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 18 | tsuyama
# Processing Record 40 of Set 18 | coolum beach
# Processing Record 41 of Set 18 | port hedland
# Processing Record 42 of Set 18 | andselv
# City not found. Skipping...
# Processing Record 43 of Set 18 | sola
# Processing Record 44 of Set 18 | mumford
# Processing Record 45 of Set 18 | bardiyah
# Processing Record 46 of Set 18 | rocha
# Processing Record 47 of Set 18 | hastings
# Processing Record 48 of Set 18 | kolda
# Processing Record 49 of Set 18 | amahai
# Processing Record 50 of Set 18 | dudinka
# Processing Record 1 of Set 19 | portland
# Processing Record 2 of Set 19 | bull savanna
# Processing Record 3 of Set 19 | riachao das neves
# Processing Record 4 of Set 19 | pagudpud
# Processing Record 5 of Set 19 | kukuna
# Processing Record 6 of Set 19 | nome
# Processing Record 7 of Set 19 | breves
# Processing Record 8 of Set 19 | ibanda
# Processing Record 9 of Set 19 | korla
# Processing Record 10 of Set 19 | luganville
# Processing Record 11 of Set 19 | nyurba
# Processing Record 12 of Set 19 | salalah
# Processing Record 13 of Set 19 | chicama
# Processing Record 14 of Set 19 | lethem
# Processing Record 15 of Set 19 | vostochnyy
# Processing Record 16 of Set 19 | banda aceh
# Processing Record 17 of Set 19 | champerico
# Processing Record 18 of Set 19 | dalbandin
# Processing Record 19 of Set 19 | la ronge
# Processing Record 20 of Set 19 | bassano
# Processing Record 21 of Set 19 | beaverlodge
# Processing Record 22 of Set 19 | kieta
# Processing Record 23 of Set 19 | codrington
# Processing Record 24 of Set 19 | vardo
# Processing Record 25 of Set 19 | eydhafushi
# Processing Record 26 of Set 19 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 19 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 19 | ribeira grande
# Processing Record 29 of Set 19 | itabira
# Processing Record 30 of Set 19 | teguise
# Processing Record 31 of Set 19 | pisco
# Processing Record 32 of Set 19 | corinto
# Processing Record 33 of Set 19 | carutapera
# Processing Record 34 of Set 19 | state college
# Processing Record 35 of Set 19 | surt
# Processing Record 36 of Set 19 | palmas bellas
# Processing Record 37 of Set 19 | provideniya
# Processing Record 38 of Set 19 | waipawa
# Processing Record 39 of Set 19 | lashio
# Processing Record 40 of Set 19 | fare
# Processing Record 41 of Set 19 | avera
# Processing Record 42 of Set 19 | george
# Processing Record 43 of Set 19 | hofn
# Processing Record 44 of Set 19 | grindavik
# Processing Record 45 of Set 19 | dauriya
# Processing Record 46 of Set 19 | feicheng
# Processing Record 47 of Set 19 | kirakira
# Processing Record 48 of Set 19 | viedma
# Processing Record 49 of Set 19 | oga
# Processing Record 50 of Set 19 | nuuk
# Processing Record 1 of Set 20 | gorom-gorom
# Processing Record 2 of Set 20 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 20 | alice springs
# Processing Record 4 of Set 20 | vostok
# Processing Record 5 of Set 20 | malakwal
# Processing Record 6 of Set 20 | guerrero negro
# Processing Record 7 of Set 20 | babu
# Processing Record 8 of Set 20 | jalingo
# Processing Record 9 of Set 20 | klaksvik
# Processing Record 10 of Set 20 | muravlenko
# Processing Record 11 of Set 20 | namibe
# Processing Record 12 of Set 20 | labuan
# Processing Record 13 of Set 20 | waterboro
# Processing Record 14 of Set 20 | boljarovo
# City not found. Skipping...
# Processing Record 15 of Set 20 | utiroa
# City not found. Skipping...
# Processing Record 16 of Set 20 | yasnyy
# Processing Record 17 of Set 20 | mount darwin
# Processing Record 18 of Set 20 | port hardy
# Processing Record 19 of Set 20 | huilong
# Processing Record 20 of Set 20 | methoni
# Processing Record 21 of Set 20 | nador
# Processing Record 22 of Set 20 | nacala
# Processing Record 23 of Set 20 | tolaga bay
# Processing Record 24 of Set 20 | owatonna
# Processing Record 25 of Set 20 | broken hill
# Processing Record 26 of Set 20 | acapulco
# Processing Record 27 of Set 20 | talcahuano
# Processing Record 28 of Set 20 | anito
# Processing Record 29 of Set 20 | oranjestad
# Processing Record 30 of Set 20 | port elizabeth
# Processing Record 31 of Set 20 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 20 | lompoc
# Processing Record 33 of Set 20 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 20 | norman wells
# Processing Record 35 of Set 20 | utrecht
# Processing Record 36 of Set 20 | esperance
# Processing Record 37 of Set 20 | wilmington
# Processing Record 38 of Set 20 | yeppoon
# Processing Record 39 of Set 20 | maumere
# Processing Record 40 of Set 20 | qasigiannguit
# Processing Record 41 of Set 20 | magole
# Processing Record 42 of Set 20 | kanniyakumari
# Processing Record 43 of Set 20 | kautokeino
# Processing Record 44 of Set 20 | la asuncion
# Processing Record 45 of Set 20 | pak phanang
# Processing Record 46 of Set 20 | tezu
# Processing Record 47 of Set 20 | zeya
# Processing Record 48 of Set 20 | tambura
# Processing Record 49 of Set 20 | shieli
# Processing Record 50 of Set 20 | stornoway
# Processing Record 1 of Set 21 | saint-francois
# Processing Record 2 of Set 21 | gardan diwal
# City not found. Skipping...
# Processing Record 3 of Set 21 | fort morgan
# Processing Record 4 of Set 21 | lieksa
# Processing Record 5 of Set 21 | correntina
# Processing Record 6 of Set 21 | belyy yar
# Processing Record 7 of Set 21 | oslo
# Processing Record 8 of Set 21 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 21 | aykhal
# Processing Record 10 of Set 21 | kununurra
# Processing Record 11 of Set 21 | bontang
# Processing Record 12 of Set 21 | dvinskoy
# Processing Record 13 of Set 21 | candido mendes
# Processing Record 14 of Set 21 | ngawen
# Processing Record 15 of Set 21 | kita
# Processing Record 16 of Set 21 | yerbogachen
# Processing Record 17 of Set 21 | kefamenanu
# Processing Record 18 of Set 21 | mangrol
# Processing Record 19 of Set 21 | leshukonskoye
# Processing Record 20 of Set 21 | tarbes
# Processing Record 21 of Set 21 | rovaniemi
# Processing Record 22 of Set 21 | tikrit
# Processing Record 23 of Set 21 | rauma
# Processing Record 24 of Set 21 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 21 | san ignacio
# Processing Record 26 of Set 21 | murgab
# Processing Record 27 of Set 21 | camopi
# Processing Record 28 of Set 21 | tiznit
# Processing Record 29 of Set 21 | vila velha
# Processing Record 30 of Set 21 | bandarbeyla
# Processing Record 31 of Set 21 | yairipok
# Processing Record 32 of Set 21 | kargat
# Processing Record 33 of Set 21 | wuzhou
# Processing Record 34 of Set 21 | jalu
# Processing Record 35 of Set 21 | diamantino
# Processing Record 36 of Set 21 | mindelo
# Processing Record 37 of Set 21 | kyzyl-suu
# Processing Record 38 of Set 21 | kochki
# Processing Record 39 of Set 21 | camacha
# Processing Record 40 of Set 21 | christchurch
# Processing Record 41 of Set 21 | baracoa
# Processing Record 42 of Set 21 | kantang
# Processing Record 43 of Set 21 | villa carlos paz
# Processing Record 44 of Set 21 | omboue
# Processing Record 45 of Set 21 | pahrump
# Processing Record 46 of Set 21 | contai
# Processing Record 47 of Set 21 | bay-khaak
# Processing Record 48 of Set 21 | puerto leguizamo
# Processing Record 49 of Set 21 | toplita
# City not found. Skipping...
# Processing Record 50 of Set 21 | nanortalik
# Processing Record 1 of Set 22 | gamba
# Processing Record 2 of Set 22 | piacabucu
# Processing Record 3 of Set 22 | sabang
# Processing Record 4 of Set 22 | odweyne
# Processing Record 5 of Set 22 | villiers
# Processing Record 6 of Set 22 | north platte
# Processing Record 7 of Set 22 | lagoa
# Processing Record 8 of Set 22 | ndele
# Processing Record 9 of Set 22 | mahebourg
# Processing Record 10 of Set 22 | pochutla
# Processing Record 11 of Set 22 | srivardhan
# Processing Record 12 of Set 22 | palatka
# Processing Record 13 of Set 22 | komsomolets
# Processing Record 14 of Set 22 | charters towers
# Processing Record 15 of Set 22 | port augusta
# Processing Record 16 of Set 22 | vila
# Processing Record 17 of Set 22 | izberbash
# Processing Record 18 of Set 22 | lahat
# Processing Record 19 of Set 22 | wahiawa
# Processing Record 20 of Set 22 | eureka
# Processing Record 21 of Set 22 | tuatapere
# Processing Record 22 of Set 22 | mayya
# Processing Record 23 of Set 22 | alta floresta
# Processing Record 24 of Set 22 | lazaro cardenas
# Processing Record 25 of Set 22 | samana
# Processing Record 26 of Set 22 | lensk
# Processing Record 27 of Set 22 | phan thiet
# Processing Record 28 of Set 22 | gunjur
# Processing Record 29 of Set 22 | paysandu
# Processing Record 30 of Set 22 | manolas
# Processing Record 31 of Set 22 | aripuana
# Processing Record 32 of Set 22 | chapais
# Processing Record 33 of Set 22 | innisfail
# Processing Record 34 of Set 22 | roma
# Processing Record 35 of Set 22 | weston
# Processing Record 36 of Set 22 | padre bernardo
# Processing Record 37 of Set 22 | mizpe ramon
# City not found. Skipping...
# Processing Record 38 of Set 22 | rumuruti
# Processing Record 39 of Set 22 | jodar
# Processing Record 40 of Set 22 | rancho palos verdes
# Processing Record 41 of Set 22 | fevralsk
# City not found. Skipping...
# Processing Record 42 of Set 22 | acajutla
# Processing Record 43 of Set 22 | temaraia
# City not found. Skipping...
# Processing Record 44 of Set 22 | nakambala
# Processing Record 45 of Set 22 | nueve de julio
# Processing Record 46 of Set 22 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 22 | miranda
# Processing Record 48 of Set 22 | ilulissat
# Processing Record 49 of Set 22 | ahuimanu
# Processing Record 50 of Set 22 | lisa
# Processing Record 1 of Set 23 | lindsay
# Processing Record 2 of Set 23 | kerouane
# Processing Record 3 of Set 23 | pipri
# Processing Record 4 of Set 23 | augusto correa
# Processing Record 5 of Set 23 | turka
# Processing Record 6 of Set 23 | ixtapa
# Processing Record 7 of Set 23 | yanan
# City not found. Skipping...
# Processing Record 8 of Set 23 | bamnet narong
# Processing Record 9 of Set 23 | sable-sur-sarthe
# Processing Record 10 of Set 23 | baghdad
# Processing Record 11 of Set 23 | salas
# Processing Record 12 of Set 23 | boston
# Processing Record 13 of Set 23 | teya
# Processing Record 14 of Set 23 | siukh
# Processing Record 15 of Set 23 | baglung
# Processing Record 16 of Set 23 | bonthe
# Processing Record 17 of Set 23 | rantepao
# Processing Record 18 of Set 23 | najran
# Processing Record 19 of Set 23 | rameswaram
# Processing Record 20 of Set 23 | sioux lookout
# Processing Record 21 of Set 23 | grunberg
# Processing Record 22 of Set 23 | tiarei
# Processing Record 23 of Set 23 | darhan
# Processing Record 24 of Set 23 | piopio
# Processing Record 25 of Set 23 | lyngseidet
# Processing Record 26 of Set 23 | tual
# Processing Record 27 of Set 23 | udachnyy
# Processing Record 28 of Set 23 | pangkalanbuun
# Processing Record 29 of Set 23 | punta cardon
# Processing Record 30 of Set 23 | noyabrsk
# Processing Record 31 of Set 23 | sao joao da barra
# Processing Record 32 of Set 23 | nizhniy kuranakh
# Processing Record 33 of Set 23 | mayumba
# Processing Record 34 of Set 23 | williams lake
# Processing Record 35 of Set 23 | harbin
# Processing Record 36 of Set 23 | itarema
# Processing Record 37 of Set 23 | moranbah
# Processing Record 38 of Set 23 | vikindu
# Processing Record 39 of Set 23 | bud
# Processing Record 40 of Set 23 | cam ranh
# Processing Record 41 of Set 23 | srednekolymsk
# Processing Record 42 of Set 23 | vestmannaeyjar
# Processing Record 43 of Set 23 | tayu
# Processing Record 44 of Set 23 | polovinnoye
# Processing Record 45 of Set 23 | qinzhou
# Processing Record 46 of Set 23 | tawnat
# City not found. Skipping...
# Processing Record 47 of Set 23 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 23 | byron bay
# Processing Record 49 of Set 23 | seoul
# Processing Record 50 of Set 23 | muros
# Processing Record 1 of Set 24 | aizpute
# Processing Record 2 of Set 24 | kokoda
# Processing Record 3 of Set 24 | zhuji
# Processing Record 4 of Set 24 | nargana
# Processing Record 5 of Set 24 | gisborne
# Processing Record 6 of Set 24 | port blair
# Processing Record 7 of Set 24 | porto velho
# Processing Record 8 of Set 24 | ust-ishim
# Processing Record 9 of Set 24 | weatherford
# Processing Record 10 of Set 24 | mugur-aksy
# Processing Record 11 of Set 24 | dong hoi
# Processing Record 12 of Set 24 | lattes
# Processing Record 13 of Set 24 | padang
# Processing Record 14 of Set 24 | kudahuvadhoo
# Processing Record 15 of Set 24 | chumikan
# Processing Record 16 of Set 24 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 24 | oriximina
# Processing Record 18 of Set 24 | kuryk
# Processing Record 19 of Set 24 | onokhoy
# Processing Record 20 of Set 24 | umm lajj
# Processing Record 21 of Set 24 | calama
# Processing Record 22 of Set 24 | tommot
# Processing Record 23 of Set 24 | berdigestyakh
# Processing Record 24 of Set 24 | sisimiut
# Processing Record 25 of Set 24 | pushkinskiye gory
# Processing Record 26 of Set 24 | okha
# Processing Record 27 of Set 24 | maraa
# Processing Record 28 of Set 24 | pingliang
# Processing Record 29 of Set 24 | lingao
# Processing Record 30 of Set 24 | jilmah
# City not found. Skipping...
# Processing Record 31 of Set 24 | jishu
# Processing Record 32 of Set 24 | talnakh
# Processing Record 33 of Set 24 | minsk
# Processing Record 34 of Set 24 | tarpon springs
# Processing Record 35 of Set 24 | kichera
# Processing Record 36 of Set 24 | srandakan
# Processing Record 37 of Set 24 | mecca
# Processing Record 38 of Set 24 | mawlaik
# Processing Record 39 of Set 24 | fuling
# Processing Record 40 of Set 24 | carora
# Processing Record 41 of Set 24 | port moresby
# Processing Record 42 of Set 24 | biak
# Processing Record 43 of Set 24 | nchelenge
# Processing Record 44 of Set 24 | pangnirtung
# Processing Record 45 of Set 24 | miraflores
# Processing Record 46 of Set 24 | karasburg
# Processing Record 47 of Set 24 | yanji
# Processing Record 48 of Set 24 | lifford
# Processing Record 49 of Set 24 | goderich
# Processing Record 50 of Set 24 | hillsborough
# Processing Record 1 of Set 25 | poronaysk
# Processing Record 2 of Set 25 | diego de almagro
# Processing Record 3 of Set 25 | seddon
# Processing Record 4 of Set 25 | salitral
# Processing Record 5 of Set 25 | burica
# City not found. Skipping...
# Processing Record 6 of Set 25 | ghorawal
# Processing Record 7 of Set 25 | vagay
# Processing Record 8 of Set 25 | beaupre
# Processing Record 9 of Set 25 | namatanai
# Processing Record 10 of Set 25 | dicabisagan
# Processing Record 11 of Set 25 | sambava
# Processing Record 12 of Set 25 | fort frances
# Processing Record 13 of Set 25 | comodoro rivadavia
# Processing Record 14 of Set 25 | karmana
# City not found. Skipping...
# Processing Record 15 of Set 25 | trincomalee
# Processing Record 16 of Set 25 | ye
# City not found. Skipping...
# Processing Record 17 of Set 25 | nevsehir
# Processing Record 18 of Set 25 | manzil tamim
# City not found. Skipping...
# Processing Record 19 of Set 25 | wetaskiwin
# Processing Record 20 of Set 25 | goba
# Processing Record 21 of Set 25 | yefira
# City not found. Skipping...
# Processing Record 22 of Set 25 | oktyabrskiy
# Processing Record 23 of Set 25 | loandjili
# Processing Record 24 of Set 25 | porto novo
# Processing Record 25 of Set 25 | purranque
# Processing Record 26 of Set 25 | gallup
# Processing Record 27 of Set 25 | prievidza
# Processing Record 28 of Set 25 | hualmay
# Processing Record 29 of Set 25 | hasaki
# Processing Record 30 of Set 25 | pundaguitan
# Processing Record 31 of Set 25 | huaraz
# Processing Record 32 of Set 25 | bilibino
# Processing Record 33 of Set 25 | kuytun
# Processing Record 34 of Set 25 | englewood
# Processing Record 35 of Set 25 | atasu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ushuaia      AR -54.80  -68.30     59.00        54          75
# 1           Tabriz      IR  38.08   46.29     51.80        29           0
# 2       Chokurdakh      RU  70.63  147.92      0.21        94         100
# 3     Beringovskiy      RU  63.05  179.32     24.13        95         100
# 4           Faanui      PF -16.48 -151.75     80.26        79          27
# 5              Nau      TJ  40.15   69.37     42.80        70         100
# 6  Haines Junction      CA  60.75 -137.51     14.00        56         100
# 7            Basco      PH  20.45  121.97     79.90        81         100
# 8      East London      ZA -33.02   27.91     65.43        83          73
# 9         Bengkulu      ID  -3.80  102.27     75.45        88          99
#
#    Wind Speed                 Date Currrent Description
# 0       18.34  2020-11-01 22:45:34        broken clouds
# 1        6.93  2020-11-01 22:40:41            clear sky
# 2       10.96  2020-11-01 22:45:34           light snow
# 3        2.98  2020-11-01 22:45:35      overcast clouds
# 4       20.31  2020-11-01 22:45:35           light rain
# 5        4.47  2020-11-01 22:45:35      overcast clouds
# 6        2.24  2020-11-01 22:45:35      overcast clouds
# 7       29.71  2020-11-01 22:45:36      overcast clouds
# 8       14.47  2020-11-01 22:45:36           light rain
# 9        4.56  2020-11-01 22:45:36      overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
